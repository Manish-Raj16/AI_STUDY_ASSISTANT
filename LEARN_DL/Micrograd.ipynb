# %%
import math
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
def f(x):
    return 3*x**2 + 2*x

# f(4.0)
f(2.0)
# Out:
# 16.0

# %%
# a = arrange(-5,5,0.50)
xs = np.arange(-5,5,0.25)
ys = f(xs) #here now every numbers work for the function which is declared 
plt.plot(xs,ys)

# %%
# more complex of the micrograd like understanding of the derivation for the neural networks
h = 0000000.1
a = 2.0
b = -3.0
c = 10 

d1 = a*b + c
c+=h
d2 = a*b+c

print('slope1', d1)
# after altering the d1 with addition of either 1 value.
print('slope2', d2)
print('slope3', (d2-d1)/h )
# Out:
# slope1 4.0
# slope2 4.1
# slope3 0.9999999999999964

# %% [markdown]
# NOW WE GONNA ENTER INTO THE DEEP LEARNING -> NEURAL_NETWORKS FUNDAMENTALS.

# %%
#
